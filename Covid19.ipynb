# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df= pd.read_csv('/home/boss/Aditya/college/Sem 5/DAV/csv/covid_19_india.csv', parse_dates=['Date'])

# %%
df
# Out:
#          Sno       Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0          1 2020-01-30  6:00 PM               Kerala                       1
# 1          2 2020-01-31  6:00 PM               Kerala                       1
# 2          3 2020-02-01  6:00 PM               Kerala                       2
# 3          4 2020-02-02  6:00 PM               Kerala                       3
# 4          5 2020-02-03  6:00 PM               Kerala                       3
# ...      ...        ...      ...                  ...                     ...
# 18105  18106 2021-08-11  8:00 AM            Telangana                       -
# 18106  18107 2021-08-11  8:00 AM              Tripura                       -
# 18107  18108 2021-08-11  8:00 AM          Uttarakhand                       -
# 18108  18109 2021-08-11  8:00 AM        Uttar Pradesh                       -
# 18109  18110 2021-08-11  8:00 AM          West Bengal                       -
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18110 entries, 0 to 18109
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       18110 non-null  int64
#  1   Date                      18110 non-null  datetime64[ns]
#  2   Time                      18110 non-null  object
#  3   State/UnionTerritory      18110 non-null  object
#  4   ConfirmedIndianNational   18110 non-null  object
#  5   ConfirmedForeignNational  18110 non-null  object
#  6   Cured                     18110 non-null  int64
#  7   Deaths                    18110 non-null  int64
#  8   Confirmed                 18110 non-null  int64
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 1.2+ MB

# %%
df1= df[df['Date'].between('2020-07-01', '2020-09-30')]
df1
# Out:
#        Sno       Date     Time         State/UnionTerritory  \
# 3603  3604 2020-07-01  8:00 AM  Andaman and Nicobar Islands
# 3604  3605 2020-07-01  8:00 AM               Andhra Pradesh
# 3605  3606 2020-07-01  8:00 AM            Arunachal Pradesh
# 3606  3607 2020-07-01  8:00 AM                        Assam
# 3607  3608 2020-07-01  8:00 AM                        Bihar
# ...    ...        ...      ...                          ...
# 6836  6837 2020-09-30  8:00 AM                    Telengana
# 6837  6838 2020-09-30  8:00 AM                      Tripura
# 6838  6839 2020-09-30  8:00 AM                  Uttarakhand
# 6839  6840 2020-09-30  8:00 AM                Uttar Pradesh
# 6840  6841 2020-09-30  8:00 AM                  West Bengal
#
#      ConfirmedIndianNational ConfirmedForeignNational   Cured  Deaths  \
# 3603                       -                        -      50       0
# 3604                       -                        -    6511     187
# ...

# %%
df1.groupby('State/UnionTerritory')[['Date','Deaths']].max()
# Out:
#                                                Date  Deaths
# State/UnionTerritory
# Andaman and Nicobar Islands              2020-09-30      53
# Andhra Pradesh                           2020-09-30    5780
# Arunachal Pradesh                        2020-09-30      16
# Assam                                    2020-09-30     680
# Bihar                                    2020-09-30     894
# Cases being reassigned to states         2020-07-18       0
# Chandigarh                               2020-09-30     158
# Chhattisgarh                             2020-09-30     916
# Dadra and Nagar Haveli and Daman and Diu 2020-09-30       2
# Delhi                                    2020-09-30    5320
# Goa                                      2020-09-30     419
# Gujarat                                  2020-09-30    3439
# Haryana                                  2020-09-30    1356
# Himachal Pradesh                         2020-09-30     183
# ...

# %%
df1
# Out:
#        Sno       Date     Time         State/UnionTerritory  \
# 3603  3604 2020-07-01  8:00 AM  Andaman and Nicobar Islands
# 3604  3605 2020-07-01  8:00 AM               Andhra Pradesh
# 3605  3606 2020-07-01  8:00 AM            Arunachal Pradesh
# 3606  3607 2020-07-01  8:00 AM                        Assam
# 3607  3608 2020-07-01  8:00 AM                        Bihar
# ...    ...        ...      ...                          ...
# 6836  6837 2020-09-30  8:00 AM                    Telengana
# 6837  6838 2020-09-30  8:00 AM                      Tripura
# 6838  6839 2020-09-30  8:00 AM                  Uttarakhand
# 6839  6840 2020-09-30  8:00 AM                Uttar Pradesh
# 6840  6841 2020-09-30  8:00 AM                  West Bengal
#
#      ConfirmedIndianNational ConfirmedForeignNational   Cured  Deaths  \
# 3603                       -                        -      50       0
# 3604                       -                        -    6511     187
# ...

# %%
df1.groupby('State/UnionTerritory')[['Date','Cured']].max()
# Out:
#                                                Date    Cured
# State/UnionTerritory
# Andaman and Nicobar Islands              2020-09-30     3587
# Andhra Pradesh                           2020-09-30   622136
# Arunachal Pradesh                        2020-09-30     6743
# Assam                                    2020-09-30   144002
# Bihar                                    2020-09-30   168025
# Cases being reassigned to states         2020-07-18        0
# Chandigarh                               2020-09-30     9598
# Chhattisgarh                             2020-09-30    78514
# Dadra and Nagar Haveli and Daman and Diu 2020-09-30     2910
# Delhi                                    2020-09-30   243481
# Goa                                      2020-09-30    27781
# Gujarat                                  2020-09-30   115727
# Haryana                                  2020-09-30   110814
# Himachal Pradesh                         2020-09-30    10991
# ...

# %%
df1.groupby('State/UnionTerritory')[['Date','Confirmed']].max()
# Out:
#                                                Date  Confirmed
# State/UnionTerritory
# Andaman and Nicobar Islands              2020-09-30       3821
# Andhra Pradesh                           2020-09-30     687351
# Arunachal Pradesh                        2020-09-30       9553
# Assam                                    2020-09-30     177221
# Bihar                                    2020-09-30     181285
# Cases being reassigned to states         2020-07-18       6915
# Chandigarh                               2020-09-30      11816
# Chhattisgarh                             2020-09-30     110655
# Dadra and Nagar Haveli and Daman and Diu 2020-09-30       3032
# Delhi                                    2020-09-30     276325
# Goa                                      2020-09-30      32777
# Gujarat                                  2020-09-30     135842
# Haryana                                  2020-09-30     126974
# Himachal Pradesh                         2020-09-30      14747
# ...

# %%
df[df['Date'].dt.day==6]
# Out:
#          Sno       Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 7          8 2020-02-06  6:00 PM               Kerala                       3
# 51        52 2020-03-06  6:00 PM                Delhi                       3
# 52        53 2020-03-06  6:00 PM              Haryana                       0
# 53        54 2020-03-06  6:00 PM               Kerala                       3
# 54        55 2020-03-06  6:00 PM            Rajasthan                       1
# ...      ...        ...      ...                  ...                     ...
# 17925  17926 2021-08-06  8:00 AM            Telangana                       -
# 17926  17927 2021-08-06  8:00 AM              Tripura                       -
# 17927  17928 2021-08-06  8:00 AM          Uttarakhand                       -
# 17928  17929 2021-08-06  8:00 AM        Uttar Pradesh                       -
# 17929  17930 2021-08-06  8:00 AM          West Bengal                       -
#
# ...

# %%
df2=df.groupby('State/UnionTerritory')

# %%
df2=df[df['State/UnionTerritory'].isin(["Karnataka", "Delhi", "Madhya Pradesh", "Haryana"])]
df2
# Out:
#          Sno       Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 34        35 2020-03-02  6:00 PM                Delhi                       1
# 38        39 2020-03-03  6:00 PM                Delhi                       1
# 41        42 2020-03-04  6:00 PM              Haryana                       0
# 42        43 2020-03-04  6:00 PM                Delhi                       1
# 45        46 2020-03-05  6:00 PM                Delhi                       2
# ...      ...        ...      ...                  ...                     ...
# 18057  18058 2021-08-10  8:00 AM       Madhya Pradesh                       -
# 18082  18083 2021-08-11  8:00 AM                Delhi                       -
# 18085  18086 2021-08-11  8:00 AM              Haryana                       -
# 18089  18090 2021-08-11  8:00 AM            Karnataka                       -
# 18093  18094 2021-08-11  8:00 AM       Madhya Pradesh                       -
#
# ...

# %%
df3=df2[df2['Date'].between("1-4-20","31-3-21")]
df3
# Out:
#          Sno       Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 34        35 2020-03-02  6:00 PM                Delhi                       1
# 38        39 2020-03-03  6:00 PM                Delhi                       1
# 41        42 2020-03-04  6:00 PM              Haryana                       0
# 42        43 2020-03-04  6:00 PM                Delhi                       1
# 45        46 2020-03-05  6:00 PM                Delhi                       2
# ...      ...        ...      ...                  ...                     ...
# 13269  13270 2021-03-30  8:00 AM       Madhya Pradesh                       -
# 13294  13295 2021-03-31  8:00 AM                Delhi                       -
# 13297  13298 2021-03-31  8:00 AM              Haryana                       -
# 13301  13302 2021-03-31  8:00 AM            Karnataka                       -
# 13305  13306 2021-03-31  8:00 AM       Madhya Pradesh                       -
#
# ...

# %%
df3['Month']=df['Date'].dt.month
df3
# Out:
# /tmp/ipykernel_3963/1391967410.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Month']=df['Date'].dt.month
#          Sno       Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 34        35 2020-03-02  6:00 PM                Delhi                       1
# 38        39 2020-03-03  6:00 PM                Delhi                       1
# 41        42 2020-03-04  6:00 PM              Haryana                       0
# 42        43 2020-03-04  6:00 PM                Delhi                       1
# 45        46 2020-03-05  6:00 PM                Delhi                       2
# ...      ...        ...      ...                  ...                     ...
# ...

# %%
df4= df3.groupby('Month')

# %%
plt.plot(df4["Month"],df["Cured"])
plt.plot(df4["Month"],df["Cured"])
plt.plot(df4["Month"],df["Cured"])
plt.show()
# Out:
# /home/boss/Downloads/anaconda3/lib/python3.9/site-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 plt.plot(df4["Month"],df["Cured"])
#       2 plt.plot(df4["Month"],df["Cured"])
#       3 plt.plot(df4["Month"],df["Cured"])
#
# File ~/Downloads/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# ...
